# %% [markdown]
# Make sure GPU is enabled
# Runtime -> Change Runtime Type -> Hardware Accelerator -> GPU

# %%
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow-gpu==2.12.0
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# WARNING: Skipping tensorflow as it is not installed.
# Collecting tensorflow-gpu==2.12.0
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !git clone https://github.com/vlomme/Multi-Tacotron-Voice-Cloning.git
# Out:
# Cloning into 'Multi-Tacotron-Voice-Cloning'...
# remote: Enumerating objects: 238, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 238 (delta 76), reused 74 (delta 74), pack-reused 129 (from 1)
# Receiving objects: 100% (238/238), 1006.70 KiB | 17.66 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
cd Multi-Tacotron-Voice-Cloning/
# Out:
# /content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu<=1.14.0 (from versions: 2.12.0)
# ERROR: No matching distribution found for tensorflow-gpu<=1.14.0

# %%
# !apt-get install libportaudio2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libportaudio2 is already the newest version (19.6.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 53 not upgraded.

# %%
# !gdown https://drive.google.com/uc?id=1aQBmpflbX_ePUdXTSNE4CfEL9hdG2-O8
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1aQBmpflbX_ePUdXTSNE4CfEL9hdG2-O8
#
# but Gdown can't. Please check connections and permissions.

# %%
# !unzip pretrained.zip
# Out:
# unzip:  cannot find or open pretrained.zip, pretrained.zip.zip or pretrained.zip.ZIP.

# %%
# !python demo_cli.py -p "ex.wav" -t "Hello my friends. Я многоязычный синтез построенный на tacotron. Шла саша по шоссе и сосала сушку" --no_sound
# Out:
# Traceback (most recent call last):
#   File "/content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/demo_cli.py", line 3, in <module>
#     from synthesizer.inference import Synthesizer
#   File "/content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/synthesizer/inference.py", line 1, in <module>
#     from synthesizer.tacotron2 import Tacotron2
#   File "/content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/synthesizer/tacotron2.py", line 1, in <module>
#     from synthesizer.utils.text import text_to_sequence
#   File "/content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/synthesizer/utils/text.py", line 2, in <module>
#     from . import cleaners
#   File "/content/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/Multi-Tacotron-Voice-Cloning/synthesizer/utils/cleaners.py", line 14, in <module>
#     from unidecode import unidecode
# ModuleNotFoundError: No module named 'unidecode'

# %%
import IPython.display as ipd
print("original(оригинал)")
ipd.display(ipd.Audio('ex.wav'))#filepath to original voices (Путь до оригинального файла)
print("cloned(клонированный)")
ipd.display(ipd.Audio('demo_output_00.wav'))#filepath to synthesized voices (Путь до синтезированного файла)
# Out:
# original(оригинал)
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# cloned(клонированный)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5895/173654452.py in <cell line: 0>()
#       3 ipd.display(ipd.Audio('ex.wav'))#filepath to original voices (Путь до оригинального файла)
#       4 print("cloned(клонированный)")
# ----> 5 ipd.display(ipd.Audio('demo_output_00.wav'))#filepath to synthesized voices (Путь до синтезированного файла)
#
# /usr/local/lib/python3.12/dist-packages/IPython/lib/display.py in __init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     114         if self.data is not None and not isinstance(self.data, bytes):
#     115             if rate is None:
# --> 116                 raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     117             self.data = Audio._make_wav(data, rate, normalize)
#     118
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.
